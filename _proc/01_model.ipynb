# %% [raw]
# ---
# output-file: model.html
# title: Model
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This is just a slightly adapted version of the original LLaMA 1 code available at [this repo](https://github.com/facebookresearch/llama/tree/main/llama).

# %%
#| echo: false
#| output: asis
show_doc(ModelArgs)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L36){target="_blank" style="float:right; font-size:smaller"}
#
# ### ModelArgs
#
# >      ModelArgs (dim:int=512, n_layers:int=8, n_heads:int=8, vocab_size:int=-1,
# >                 multiple_of:int=256, norm_eps:float=1e-05,
# >                 max_batch_size:int=32, max_seq_len:int=2048)

# %%
#| echo: false
#| output: asis
show_doc(RMSNorm)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L49){target="_blank" style="float:right; font-size:smaller"}
#
# ### RMSNorm
#
# >      RMSNorm (dim:int, eps:float=1e-06)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
# ...

# %%
#| echo: false
#| output: asis
show_doc(precompute_freqs_cis)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L63){target="_blank" style="float:right; font-size:smaller"}
#
# ### precompute_freqs_cis
#
# >      precompute_freqs_cis (dim:int, end:int, theta:float=10000.0)

# %%
#| echo: false
#| output: asis
show_doc(reshape_for_broadcast)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L71){target="_blank" style="float:right; font-size:smaller"}
#
# ### reshape_for_broadcast
#
# >      reshape_for_broadcast (freqs_cis:torch.Tensor, x:torch.Tensor)

# %%
#| echo: false
#| output: asis
show_doc(apply_rotary_emb)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L79){target="_blank" style="float:right; font-size:smaller"}
#
# ### apply_rotary_emb
#
# >      apply_rotary_emb (xq:torch.Tensor, xk:torch.Tensor,
# >                        freqs_cis:torch.Tensor)

# %%
#| echo: false
#| output: asis
show_doc(LoRA)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L92){target="_blank" style="float:right; font-size:smaller"}
#
# ### LoRA
#
# >      LoRA (input_dim, output_dim)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
# ...

# %%
#| echo: false
#| output: asis
show_doc(Attention)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L121){target="_blank" style="float:right; font-size:smaller"}
#
# ### Attention
#
# >      Attention (args:__main__.ModelArgs)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
# ...

# %%
#| echo: false
#| output: asis
show_doc(FeedForward)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L220){target="_blank" style="float:right; font-size:smaller"}
#
# ### FeedForward
#
# >      FeedForward (dim:int, hidden_dim:int, multiple_of:int)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
# ...

# %%
#| echo: false
#| output: asis
show_doc(TransformerBlock)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L245){target="_blank" style="float:right; font-size:smaller"}
#
# ### TransformerBlock
#
# >      TransformerBlock (layer_id:int, args:__main__.ModelArgs)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# ...

# %%
#| echo: false
#| output: asis
show_doc(Transformer)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L265){target="_blank" style="float:right; font-size:smaller"}
#
# ### Transformer
#
# >      Transformer (params:__main__.ModelArgs)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
# ...

# %%
#| echo: false
#| output: asis
show_doc(FunctionModel)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L310){target="_blank" style="float:right; font-size:smaller"}
#
# ### FunctionModel
#
# >      FunctionModel (model, func_dict, inference_mode='func_embedding',
# >                     load_embed_path=None)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# ...

# %%
#| echo: false
#| output: asis
show_doc(sample_top_p)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L336){target="_blank" style="float:right; font-size:smaller"}
#
# ### sample_top_p
#
# >      sample_top_p (probs, p)

# %%
#| echo: false
#| output: asis
show_doc(setup_model_parallel)
# Out:
# ---
#
# [source](https://github.com/stroopwafl/toolken/blob/main/toolken/model.py#L351){target="_blank" style="float:right; font-size:smaller"}
#
# ### setup_model_parallel
#
# >      setup_model_parallel ()
